# %%
# !rm -rf /kaggle/working/*
# %cd /kaggle/working
# !git clone https://github.com/phanhoang1803/ISIC2024.git
# %cd ISIC2024/src

# %%
# !python train.py \
--root_dir "/kaggle/input/isic-2024-challenge" \
--architecture "CombinedModel" \
--model_name "efficientnet_b2" \
--feature_engineering \
--data_ratio 30 \
--learning_rate 1e-3 \
--weight_decay 1e-2 \
--img_size 256 \
--patience 20 \
--train_batch_size 64

# --feature_engineering \

# --extra_data_dirs /kaggle/input/isic-2018-jpg-256x256-resized /kaggle/input/isic-2019-jpg-256x256-resized /kaggle/input/isic-2020-jpg-256x256-resized \

# --train_batch_size 32


# --extra_data_dirs /kaggle/input/isic-2018-jpg-256x256-resized \

# %%
# !python train.py \
# --root_dir "/kaggle/input/isic-2024-challenge" \
# --checkpoint_path "/kaggle/input/tf-efficientnet/pytorch/tf-efficientnet-b0/1/tf_efficientnet_b0_aa-827b6e33.pth" \
# --architecture "EfficientNet"
